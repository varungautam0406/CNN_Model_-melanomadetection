# %% [markdown]
# <a href="https://colab.research.google.com/github/varungautam0406/CNN_Model_-melanomadetection/blob/main/Varunkumar_nn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data
# #### To do: Take necessary actions to read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
## If you are using the data by mounting the google drive, use the following :
from google.colab import drive
drive.mount('/content/gdrive')

##Ref:https://towardsdatascience.com/downloading-datasets-into-google-drive-via-google-colab-bcb1b30b0166
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
data_dir_train = pathlib.Path("/content/gdrive/MyDrive/CancerDetection/Train")
data_dir_test = pathlib.Path('/content/gdrive/My Drive/CancerDetection/Test')

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2259
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split= 0.2,
    subset= 'training',
    image_size=(img_height,img_width),
    batch_size = batch_size
)
# Out:
# Found 2259 files belonging to 9 classes.
# Using 1808 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split= 0.2,
    subset= 'validation',
    image_size=(img_height,img_width),
    batch_size = batch_size
)
# Out:
# Found 2259 files belonging to 9 classes.
# Using 451 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list. 
# You can find the class names in the class_names attribute on these datasets. 
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
for i in range(9): 
  plt.subplot(3, 3, i + 1)
  image = plt.imread(str(list(data_dir_train.glob(class_names[i]+'/*.jpg'))[1]))
  plt.title(class_names[i])
  plt.imshow(image)
### your code goes here, you can use training or validation data to visualize

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
### Your code goes here
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
num_classes = 9
model = Sequential([
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
])
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu', input_shape = (180, 180, 32)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(num_classes, activation = "softmax"))

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 32)      2432
#
#  conv2d_1 (Conv2D)           (None, 180, 180, 32)      25632
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 90, 90, 32)        25632
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 45, 45, 64)        51264
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 22, 22, 64)        102464
#
#  max_pooling2d_3 (MaxPooling  (None, 11, 11, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 11, 11, 64)        0
#
#  flatten (Flatten)           (None, 7744)              0
#
#  dense (Dense)               (None, 9)                 69705
#
# =================================================================
# Total params: 277,129
# Trainable params: 277,129
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 57/57 [==============================] - 771s 3s/step - loss: 2.0483 - accuracy: 0.1969 - val_loss: 1.9593 - val_accuracy: 0.2661
# Epoch 2/20
# 57/57 [==============================] - 4s 77ms/step - loss: 1.8758 - accuracy: 0.2926 - val_loss: 1.6630 - val_accuracy: 0.4035
# Epoch 3/20
# 57/57 [==============================] - 4s 77ms/step - loss: 1.7316 - accuracy: 0.3645 - val_loss: 1.6246 - val_accuracy: 0.3947
# Epoch 4/20
# 57/57 [==============================] - 4s 77ms/step - loss: 1.6205 - accuracy: 0.4043 - val_loss: 1.7482 - val_accuracy: 0.3259
# Epoch 5/20
# 57/57 [==============================] - 4s 77ms/step - loss: 1.6008 - accuracy: 0.4226 - val_loss: 1.5572 - val_accuracy: 0.4368
# Epoch 6/20
# 57/57 [==============================] - 4s 77ms/step - loss: 1.5169 - accuracy: 0.4685 - val_loss: 1.5138 - val_accuracy: 0.4457
# Epoch 7/20
# 57/57 [==============================] - 4s 77ms/step - loss: 1.4388 - accuracy: 0.5011 - val_loss: 1.4920 - val_accuracy: 0.4590
# Epoch 8/20
# 57/57 [==============================] - 4s 78ms/step - loss: 1.4284 - accuracy: 0.5028 - val_loss: 1.5062 - val_accuracy: 0.4634
# Epoch 9/20
# 57/57 [==============================] - 4s 78ms/step - loss: 1.3603 - accuracy: 0.5299 - val_loss: 1.5801 - val_accuracy: 0.4324
# Epoch 10/20
# 57/57 [==============================] - 4s 78ms/step - loss: 1.3300 - accuracy: 0.5404 - val_loss: 1.4066 - val_accuracy: 0.5055
# Epoch 11/20
# 57/57 [==============================] - 4s 78ms/step - loss: 1.3121 - accuracy: 0.5404 - val_loss: 1.4556 - val_accuracy: 0.5188
# Epoch 12/20
# 57/57 [==============================] - 5s 80ms/step - loss: 1.2508 - accuracy: 0.5680 - val_loss: 1.4755 - val_accuracy: 0.4878
# Epoch 13/20
# 57/57 [==============================] - 4s 79ms/step - loss: 1.2349 - accuracy: 0.5603 - val_loss: 1.5203 - val_accuracy: 0.4812
# Epoch 14/20
# 57/57 [==============================] - 4s 78ms/step - loss: 1.1653 - accuracy: 0.5924 - val_loss: 1.4123 - val_accuracy: 0.5078
# Epoch 15/20
# 57/57 [==============================] - 4s 78ms/step - loss: 1.1335 - accuracy: 0.5946 - val_loss: 1.7039 - val_accuracy: 0.4989
# Epoch 16/20
# 57/57 [==============================] - 4s 78ms/step - loss: 1.1204 - accuracy: 0.6067 - val_loss: 1.4823 - val_accuracy: 0.4834
# Epoch 17/20
# 57/57 [==============================] - 4s 77ms/step - loss: 1.1108 - accuracy: 0.6117 - val_loss: 1.5457 - val_accuracy: 0.4945
# Epoch 18/20
# 57/57 [==============================] - 4s 77ms/step - loss: 0.9951 - accuracy: 0.6394 - val_loss: 1.5126 - val_accuracy: 0.5078
# Epoch 19/20
# 57/57 [==============================] - 4s 77ms/step - loss: 0.9355 - accuracy: 0.6521 - val_loss: 1.6754 - val_accuracy: 0.4590
# Epoch 20/20
# 57/57 [==============================] - 4s 77ms/step - loss: 0.9519 - accuracy: 0.6582 - val_loss: 1.7260 - val_accuracy: 0.4945

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit

# %% [markdown]
# **Finding on the first base model**
#
# - The model is overfitting because we can also see difference in loss functions in training & test around the 10-11th epoch
#
# - The accuracy is just around 75-80% because there are enough features to remember the pattern.
#
# - But again, it's too early to comment on the overfitting & underfitting debate

# %%
# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy. 
data_augument = keras.Sequential([
                             layers.experimental.preprocessing.RandomFlip(mode="horizontal_and_vertical",input_shape=(img_height,img_width,3)),
                             layers.experimental.preprocessing.RandomRotation(0.2, fill_mode='reflect'),
                             layers.experimental.preprocessing.RandomZoom(height_factor=(0.2, 0.3), width_factor=(0.2, 0.3), fill_mode='reflect')
])

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.

plt.figure(figsize=(12, 12))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(data_augument(images)[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
# ### Todo:
# ### Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
num_classes = 9
model = Sequential([ data_augument,
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
      
])
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu', input_shape = (180, 180, 32)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(num_classes, activation = "softmax"))

# %% [markdown]
# ### Compiling the model

# %%
### Your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs
epochs=20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 57/57 [==============================] - 7s 94ms/step - loss: 2.0544 - accuracy: 0.2124 - val_loss: 2.0117 - val_accuracy: 0.2284
# Epoch 2/20
# 57/57 [==============================] - 5s 86ms/step - loss: 1.9703 - accuracy: 0.2506 - val_loss: 1.8700 - val_accuracy: 0.2794
# Epoch 3/20
# 57/57 [==============================] - 5s 86ms/step - loss: 2.0121 - accuracy: 0.2041 - val_loss: 1.9226 - val_accuracy: 0.2838
# Epoch 4/20
# 57/57 [==============================] - 5s 86ms/step - loss: 1.9054 - accuracy: 0.2915 - val_loss: 2.1801 - val_accuracy: 0.1885
# Epoch 5/20
# 57/57 [==============================] - 5s 86ms/step - loss: 2.0408 - accuracy: 0.1886 - val_loss: 2.0403 - val_accuracy: 0.1929
# Epoch 6/20
# 57/57 [==============================] - 5s 86ms/step - loss: 2.0181 - accuracy: 0.1975 - val_loss: 2.0239 - val_accuracy: 0.1951
# Epoch 7/20
# 57/57 [==============================] - 5s 87ms/step - loss: 2.0336 - accuracy: 0.2052 - val_loss: 2.0520 - val_accuracy: 0.1907
# Epoch 8/20
# 57/57 [==============================] - 5s 87ms/step - loss: 2.0187 - accuracy: 0.2129 - val_loss: 2.0300 - val_accuracy: 0.1951
# Epoch 9/20
# 57/57 [==============================] - 5s 87ms/step - loss: 2.0109 - accuracy: 0.2041 - val_loss: 2.0381 - val_accuracy: 0.1951
# Epoch 10/20
# 57/57 [==============================] - 5s 87ms/step - loss: 2.0102 - accuracy: 0.2069 - val_loss: 2.0329 - val_accuracy: 0.1907
# Epoch 11/20
# 57/57 [==============================] - 5s 88ms/step - loss: 2.0093 - accuracy: 0.2080 - val_loss: 2.0347 - val_accuracy: 0.1951
# Epoch 12/20
# 57/57 [==============================] - 5s 87ms/step - loss: 2.0137 - accuracy: 0.2002 - val_loss: 2.0300 - val_accuracy: 0.1885
# Epoch 13/20
# 57/57 [==============================] - 5s 86ms/step - loss: 2.0107 - accuracy: 0.2058 - val_loss: 2.0359 - val_accuracy: 0.1951
# Epoch 14/20
# 57/57 [==============================] - 5s 86ms/step - loss: 2.0110 - accuracy: 0.2035 - val_loss: 2.0368 - val_accuracy: 0.1929
# Epoch 15/20
# 57/57 [==============================] - 5s 86ms/step - loss: 2.0094 - accuracy: 0.1875 - val_loss: 2.0340 - val_accuracy: 0.1951
# Epoch 16/20
# 57/57 [==============================] - 5s 86ms/step - loss: 2.0081 - accuracy: 0.2140 - val_loss: 2.0232 - val_accuracy: 0.1951
# Epoch 17/20
# 57/57 [==============================] - 5s 86ms/step - loss: 2.0093 - accuracy: 0.2096 - val_loss: 2.0245 - val_accuracy: 0.1951
# Epoch 18/20
# 57/57 [==============================] - 5s 85ms/step - loss: 2.0081 - accuracy: 0.1897 - val_loss: 2.0253 - val_accuracy: 0.1907
# Epoch 19/20
# 57/57 [==============================] - 5s 86ms/step - loss: 2.0058 - accuracy: 0.2013 - val_loss: 2.0342 - val_accuracy: 0.1951
# Epoch 20/20
# 57/57 [==============================] - 5s 86ms/step - loss: 2.0292 - accuracy: 0.2113 - val_loss: 2.0357 - val_accuracy: 0.1907

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?

# %% [markdown]
# **Finding from Second Model**
#
# - There is no improvement in accuracy but we can definitely see the overfitting problem has solved due to data augmentation
#
# - We can increase the epochs to increase the accuracy so it's too early for judgement

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
##
path_list=[]
lesion_list=[]
for i in class_names:
      
    for j in data_dir_train.glob(i+'/*.jpg'):
        path_list.append(str(j))
        lesion_list.append(i)
dataframe_dict_original = dict(zip(path_list, lesion_list))
original_df = pd.DataFrame(list(dataframe_dict_original.items()),columns = ['Path','Label'])
original_df
# Out:
#                                                    Path              Label
# 0     /content/gdrive/MyDrive/CancerDetection/Train/...  actinic keratosis
# 1     /content/gdrive/MyDrive/CancerDetection/Train/...  actinic keratosis
# 2     /content/gdrive/MyDrive/CancerDetection/Train/...  actinic keratosis
# 3     /content/gdrive/MyDrive/CancerDetection/Train/...  actinic keratosis
# 4     /content/gdrive/MyDrive/CancerDetection/Train/...  actinic keratosis
# ...                                                 ...                ...
# 2254  /content/gdrive/MyDrive/CancerDetection/Train/...    vascular lesion
# 2255  /content/gdrive/MyDrive/CancerDetection/Train/...    vascular lesion
# 2256  /content/gdrive/MyDrive/CancerDetection/Train/...    vascular lesion
# 2257  /content/gdrive/MyDrive/CancerDetection/Train/...    vascular lesion
# 2258  /content/gdrive/MyDrive/CancerDetection/Train/...    vascular lesion
#
# [2259 rows x 2 columns]

# %%
dataframe_dict_original = dict(zip(path_list, lesion_list))
original_df = pd.DataFrame(list(dataframe_dict_original.items()),columns = ['Path','Label'])
original_df
# Out:
#                                                    Path              Label
# 0     /content/gdrive/MyDrive/CancerDetection/Train/...  actinic keratosis
# 1     /content/gdrive/MyDrive/CancerDetection/Train/...  actinic keratosis
# 2     /content/gdrive/MyDrive/CancerDetection/Train/...  actinic keratosis
# 3     /content/gdrive/MyDrive/CancerDetection/Train/...  actinic keratosis
# 4     /content/gdrive/MyDrive/CancerDetection/Train/...  actinic keratosis
# ...                                                 ...                ...
# 2254  /content/gdrive/MyDrive/CancerDetection/Train/...    vascular lesion
# 2255  /content/gdrive/MyDrive/CancerDetection/Train/...    vascular lesion
# 2256  /content/gdrive/MyDrive/CancerDetection/Train/...    vascular lesion
# 2257  /content/gdrive/MyDrive/CancerDetection/Train/...    vascular lesion
# 2258  /content/gdrive/MyDrive/CancerDetection/Train/...    vascular lesion
#
# [2259 rows x 2 columns]

# %%
count=[]
for i in class_names:
    count.append(len(list(data_dir_train.glob(i+'/*.jpg'))))
plt.figure(figsize=(25,10))
plt.bar(class_names,count)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# #### **Todo:** Write your findings here:
# #### - Which class has the least number of samples?
# #### - Which classes dominate the data in terms proportionate number of samples?

# %% [markdown]
# Answer-1 :- **squamous cell carcinoma** has least number of samples
#
# Answer-2:- **actinic keratosis and dermatofibroma** have proportionate number of classes.
# **melanoma and pigmented benign keratosis** have proprtionate number of classes

# %%
class_names
# Out:
# ['actinic keratosis',
#  'basal cell carcinoma',
#  'dermatofibroma',
#  'melanoma',
#  'nevus',
#  'pigmented benign keratosis',
#  'seborrheic keratosis',
#  'squamous cell carcinoma',
#  'vascular lesion']

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Augmentor
#   Downloading Augmentor-0.2.10-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (0.16.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (4.64.1)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (7.1.2)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (1.21.6)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.10

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
#path_to_training_dataset="/content/drive/MyDrive/CancerDetection/Train"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline("/content/gdrive/MyDrive/CancerDetection/Train",save_format='jpg')
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 2259 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CancerDetection/Train/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7FD7E0397310>: 100%|██████████| 500/500 [00:51<00:00,  9.68 Samples/s]
# Initialised with 2259 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CancerDetection/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FD7E2EEBB90>: 100%|██████████| 500/500 [00:47<00:00, 10.44 Samples/s]
# Initialised with 2259 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CancerDetection/Train/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7FD7E03E4D90>: 100%|██████████| 500/500 [00:57<00:00,  8.74 Samples/s]
# Initialised with 2259 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CancerDetection/Train/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7FD7E1C07B10>: 100%|██████████| 500/500 [00:58<00:00,  8.59 Samples/s]
# Initialised with 2259 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CancerDetection/Train/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7FD7E2FFF990>: 100%|██████████| 500/500 [00:44<00:00, 11.16 Samples/s]
# Initialised with 2259 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CancerDetection/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FD7E2F7C210>: 100%|██████████| 500/500 [00:40<00:00, 12.24 Samples/s]
# Initialised with 2259 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CancerDetection/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FD7E1E96F10>: 100%|██████████| 500/500 [00:40<00:00, 12.28 Samples/s]
# Initialised with 2259 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CancerDetection/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FD7FE2A8110>: 100%|██████████| 500/500 [00:48<00:00, 10.41 Samples/s]
# Initialised with 2259 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CancerDetection/Train/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1008x711 at 0x7FD7E038E510>: 100%|██████████| 500/500 [00:46<00:00, 10.83 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
data_dir_train1 = pathlib.Path("/content/gdrive/MyDrive/CancerDetection/Train/output")
image_count_train1 = len(list(data_dir_train1.glob('*/*.jpg')))
print(image_count_train1)
# Out:
# 4500

# %%
##
for i in class_names:
      
    for j in data_dir_train1.glob(i+'/*.jpg'):
        path_list.append(str(j))
        lesion_list.append(i)
dataframe_dict_original = dict(zip(path_list, lesion_list))
new_df = pd.DataFrame(list(dataframe_dict_original.items()),columns = ['Path','Label'])
new_df
# Out:
#                                                    Path              Label
# 0     /content/gdrive/MyDrive/CancerDetection/Train/...  actinic keratosis
# 1     /content/gdrive/MyDrive/CancerDetection/Train/...  actinic keratosis
# 2     /content/gdrive/MyDrive/CancerDetection/Train/...  actinic keratosis
# 3     /content/gdrive/MyDrive/CancerDetection/Train/...  actinic keratosis
# 4     /content/gdrive/MyDrive/CancerDetection/Train/...  actinic keratosis
# ...                                                 ...                ...
# 6754  /content/gdrive/MyDrive/CancerDetection/Train/...    vascular lesion
# 6755  /content/gdrive/MyDrive/CancerDetection/Train/...    vascular lesion
# 6756  /content/gdrive/MyDrive/CancerDetection/Train/...    vascular lesion
# 6757  /content/gdrive/MyDrive/CancerDetection/Train/...    vascular lesion
# 6758  /content/gdrive/MyDrive/CancerDetection/Train/...    vascular lesion
#
# [6759 rows x 2 columns]

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
new_df['Label'].value_counts()
# Out:
# melanoma                      1390
# pigmented benign keratosis    1358
# basal cell carcinoma          1139
# nevus                         1045
# squamous cell carcinoma        553
# vascular lesion                410
# actinic keratosis              335
# dermatofibroma                 281
# seborrheic keratosis           248
# Name: Label, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### **Todo**: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %%
import pathlib
data_dir_train1=pathlib.Path("/content/gdrive/MyDrive/CancerDetection/Train/output")

# %%
data_dir_train1

# %% [markdown]
# #### **Todo:** Create a training dataset

# %%
image_count_train1 = len(list(data_dir_train1.glob('*/*.jpg')))
print(image_count_train1)
# Out:
# 4500

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential


data_dir_train1=pathlib.Path("/content/gdrive/MyDrive/CancerDetection/Train/output")
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train1,
  seed=123,
  validation_split = 0.2,
  subset = "training",
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 4500 files belonging to 9 classes.
# Using 3600 files for training.

# %% [markdown]
# #### **Todo:** Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train1,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 4500 files belonging to 9 classes.
# Using 900 files for validation.

# %% [markdown]
# #### **Todo:** Create your model (make sure to include normalization)

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
num_classes = 9
model = Sequential([ 
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
      
])
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu', input_shape = (180, 180, 32)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(num_classes, activation = "softmax"))

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
## ### Your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# #### **Todo:**  Train your model

# %%
epochs =30
## Your code goes here, use 30 epochs.
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs 
)
# Out:
# Epoch 1/30
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 113/113 [==============================] - 23s 188ms/step - loss: 1.9266 - accuracy: 0.2761 - val_loss: 1.9703 - val_accuracy: 0.2633
# Epoch 2/30
# 113/113 [==============================] - 20s 173ms/step - loss: 1.7041 - accuracy: 0.3772 - val_loss: 1.6278 - val_accuracy: 0.4289
# Epoch 3/30
# 113/113 [==============================] - 21s 174ms/step - loss: 1.5301 - accuracy: 0.4533 - val_loss: 1.4891 - val_accuracy: 0.4556
# Epoch 4/30
# 113/113 [==============================] - 20s 172ms/step - loss: 1.4000 - accuracy: 0.5078 - val_loss: 1.4076 - val_accuracy: 0.4744
# Epoch 5/30
# 113/113 [==============================] - 20s 173ms/step - loss: 1.3291 - accuracy: 0.5261 - val_loss: 1.2937 - val_accuracy: 0.5467
# Epoch 6/30
# 113/113 [==============================] - 20s 173ms/step - loss: 1.2235 - accuracy: 0.5664 - val_loss: 1.1800 - val_accuracy: 0.5844
# Epoch 7/30
# 113/113 [==============================] - 21s 174ms/step - loss: 1.0207 - accuracy: 0.6411 - val_loss: 1.3506 - val_accuracy: 0.5322
# Epoch 8/30
# 113/113 [==============================] - 21s 174ms/step - loss: 0.8867 - accuracy: 0.6847 - val_loss: 1.1384 - val_accuracy: 0.6300
# Epoch 9/30
# 113/113 [==============================] - 22s 183ms/step - loss: 0.7139 - accuracy: 0.7550 - val_loss: 1.2800 - val_accuracy: 0.5822
# Epoch 10/30
# 113/113 [==============================] - 20s 173ms/step - loss: 0.6704 - accuracy: 0.7600 - val_loss: 1.2271 - val_accuracy: 0.6222
# Epoch 11/30
# 113/113 [==============================] - 20s 173ms/step - loss: 0.5728 - accuracy: 0.7961 - val_loss: 1.2100 - val_accuracy: 0.6489
# Epoch 12/30
# 113/113 [==============================] - 20s 173ms/step - loss: 0.4505 - accuracy: 0.8442 - val_loss: 1.2837 - val_accuracy: 0.6433
# Epoch 13/30
# 113/113 [==============================] - 20s 172ms/step - loss: 0.4309 - accuracy: 0.8500 - val_loss: 1.3347 - val_accuracy: 0.6400
# Epoch 14/30
# 113/113 [==============================] - 20s 172ms/step - loss: 0.3543 - accuracy: 0.8742 - val_loss: 1.4007 - val_accuracy: 0.7089
# Epoch 15/30
# 113/113 [==============================] - 20s 172ms/step - loss: 0.2953 - accuracy: 0.8892 - val_loss: 1.4746 - val_accuracy: 0.7000
# Epoch 16/30
# 113/113 [==============================] - 20s 173ms/step - loss: 0.3413 - accuracy: 0.8814 - val_loss: 1.4565 - val_accuracy: 0.6933
# Epoch 17/30
# 113/113 [==============================] - 21s 180ms/step - loss: 0.2594 - accuracy: 0.9064 - val_loss: 1.5602 - val_accuracy: 0.6889
# Epoch 18/30
# 113/113 [==============================] - 20s 174ms/step - loss: 0.2569 - accuracy: 0.9106 - val_loss: 1.5702 - val_accuracy: 0.7011
# Epoch 19/30
# 113/113 [==============================] - 20s 172ms/step - loss: 0.2284 - accuracy: 0.9281 - val_loss: 1.6073 - val_accuracy: 0.7156
# Epoch 20/30
# 113/113 [==============================] - 20s 174ms/step - loss: 0.2027 - accuracy: 0.9333 - val_loss: 1.7137 - val_accuracy: 0.6944
# Epoch 21/30
# 113/113 [==============================] - 21s 182ms/step - loss: 0.2064 - accuracy: 0.9325 - val_loss: 1.5245 - val_accuracy: 0.7289
# Epoch 22/30
# 113/113 [==============================] - 20s 174ms/step - loss: 0.1577 - accuracy: 0.9453 - val_loss: 1.5030 - val_accuracy: 0.7400
# Epoch 23/30
# 113/113 [==============================] - 20s 174ms/step - loss: 0.1576 - accuracy: 0.9567 - val_loss: 1.5713 - val_accuracy: 0.7300
# Epoch 24/30
# 113/113 [==============================] - 21s 175ms/step - loss: 0.1276 - accuracy: 0.9572 - val_loss: 1.5913 - val_accuracy: 0.7333
# Epoch 25/30
# 113/113 [==============================] - 21s 174ms/step - loss: 0.1875 - accuracy: 0.9422 - val_loss: 1.6112 - val_accuracy: 0.7244
# Epoch 26/30
# 113/113 [==============================] - 20s 173ms/step - loss: 0.1226 - accuracy: 0.9611 - val_loss: 1.4744 - val_accuracy: 0.7367
# Epoch 27/30
# 113/113 [==============================] - 21s 174ms/step - loss: 0.1606 - accuracy: 0.9511 - val_loss: 1.4642 - val_accuracy: 0.7389
# Epoch 28/30
# 113/113 [==============================] - 21s 183ms/step - loss: 0.1166 - accuracy: 0.9656 - val_loss: 1.6570 - val_accuracy: 0.7522
# Epoch 29/30
# 113/113 [==============================] - 20s 173ms/step - loss: 0.1317 - accuracy: 0.9556 - val_loss: 1.7724 - val_accuracy: 0.7344
# Epoch 30/30
# 113/113 [==============================] - 21s 174ms/step - loss: 0.1039 - accuracy: 0.9656 - val_loss: 1.5213 - val_accuracy: 0.7322

# %% [markdown]
# #### **Todo:**  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Todo:**  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?

# %% [markdown]
# - Accuracy on training data has increased by using Augmentor library
#
# - Model is still overfitting
#
# - The problem of overfitting can be solved by add more layer,neurons or adding dropout layers.
#
# - The Model can be further improved by tuning the hyperparameter
